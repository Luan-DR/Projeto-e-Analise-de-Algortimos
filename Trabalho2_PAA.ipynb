# %% [markdown]
# # Trabalho Among Us

# %% [markdown]
# Projeto e Análise de Algoritmos

# %% [markdown]
# Prof. Dr. Alan Demétrius Baria Valejo

# %% [markdown]
# Trabalho Prático 2 - Em Trenós
# Lembra do jogo Among Us, mostrado nas primeiras aulas de grafos? Ele não
# estava lá à toda. Vamos usá-lo como contexto deste trabalho prático. Nesse jogo, todas as
# personagens estão em uma nave, que está passando por diversas dificuldades técnicas.
# Assim, o papel da tripulação é cumprir tarefas para consertar a nave e manter todos em
# segurança até o final da viagem. Porém, há um impostor entre os jogadores. A tarefa dele
# é sabotar a viagem e eliminar (meu eufemismo para “matar”) os demais jogadores. Além
# disso, o impostor pode entrar na tubulação de ar da nave e se locomover entre as saídas
# do ar rapidamente.
# Neste trabalho prático você deve considerar a seguinte situação. Em um
# determinado momento do jogo, você vê alguém vestido de papai noel entrando na
# tubulação e pensa “Opa! Isso não é uma chaminé... logo, esse não é o Papai Noel de
# verdade. Deve ser um impostor. Ele está em trenós. Digo, entre nós!”. Sua tarefa, agora
# que sabe quem é o impostor, é ir até o botão de emergência para chamar uma reunião e
# delatar o meliante.
# No entanto, o falso Noel também te viu e vai tentar te eliminar antes que você
# chegue ao botão. Para isso, ele pode usar os tubos de ventilação. Considere que, como ele
# não sabe o caminho que você vai tomar, ele vai tentar chegar na sala onde o botão se
# encontra e, de lá, tentar te alcançar antes que você chame a reunião.
#
# ![image.png](data:image/png;base64,...)
#
# A sua missão neste trabalho é determinar, a partir desse momento, quem consegue
# chegar antes na sala onde o botão de emergência se encontra. Para isso, você contará com
# um grafo não-direcionado e ponderado que define o mapa do jogo - onde os vértices
# representam as salas e as arestas, os corredores entre elas, com o peso da aresta sendo o
# tempo necessário para se chegar de uma sala à outra - e a definição de onde se encontrame como se ligam as entradas da tubulação de ar. Você deve sempre considerar que o botão
# de emergência se encontra no vértice 0 e que se o tempo de chegada em tal vértice for
# igual, você tem a vantagem sobre o impostor. Ou seja, você ganha nesse caso.
# Entrada:
# A entrada apresenta um único grafo conexo, a descrição das tubulações e várias
# consultas. A primeira linha contém os valores inteiros M, E, N e C (2 ≤ M ≤ 100, 2 ≤ N
# ≤ 20, M ≤ E ≤ M2 - M, 2 ≤ C ≤ M), representando os números de salas, de ligações entre
# elas por meio de corredores, de ligações entre salas por tubulações e de consultas,
# respectivamente. Na próxima linha, encontram-se 3*E valores apresentados em triplas
# (U, V, D), (0 ≤ U,V < M, 0.5 ≤ D ≤ 10.0), que descrevem as ligações entre as salas U e V
# por meio de um corredor com comprimento D. Os indicadores de vértices são números
# inteiros, enquanto o valor de distância pertence aos reais e é apresentado com uma casa
# decimal. A seguir, são apresentados 2*N números inteiros, representando os pares (U, V),
# (0 ≤ U,V < M), que descrevem o fato de haver uma ligação entre as salas U e V por meio
# de tubos de ventilação, com distância 1 entre elas. A partir da quarta linha, há C linhas de
# consultas. Cada uma dessas linhas é composta por um inteiro, representando a sala onde
# você viu o impostor.
# Saída:
# Para cada uma das linhas de consulta, o seu programa deve imprimir “defeat”
# caso o impostor consiga chegar antes de sua personagem ao vértice 0 ou “victory”, caso
# contrário.
# Exemplo de entrada:
# 9 12 4 2
# 0 1 1.3 0 5 1.5 0 4 3.2 1 2 0.7 1 3 0.3 2 3 2.3 4 9 0.2 5 6 1.7
# 5 7 3.0 6 7 0.9 6 8 2.1 7 8 1.1
# 87755823
# 2
# 8
# Saída esperada para o exemplo:
# victory
# defeat
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #
43 39 48 40 41 40 43 40 58 41 43 41 45 45 47 47 49 48 52 49 50 50 53 51 54 53 55 53 63 56 59 57 59 58 60 59 61 59 62 60 61 60 62 60 68 62 63 63 71 64 66 64 73 65 68 66 75 67 74 67 77 71 75 71 84 72 76 73 74 73 75 74 76 74 83 75 76 76 82 77 78 77 87 77 88 78 81 78 98 82 88 83 85 84 86 89 90 89 94 91 93 95 96 95 99 96 99'
x4 = '''98'''

# %%
l1 = [int(elemento) for elemento in x1.split()]
l2 = [float(elemento) for elemento in x2.split()]
l3 = [int(elemento) for elemento in x3.split()]
consultas = [int(elemento) for elemento in x4.split()]

# %% [markdown]
# Algoritmo de Dijkstra considerando apenas l2

# %%
# Função para criar o grafo a partir dos dados de entrada
def criar_grafo(l2):
    grafo = {}
    for i in range(len(l2) // 3):
        ponto_origem = l2[i * 3]
        ponto_destino = l2[i * 3 + 1]
        distancia = l2[i * 3 + 2]
        if ponto_origem not in grafo:
            grafo[ponto_origem] = []
        grafo[ponto_origem].append((ponto_destino, distancia))
        if ponto_destino not in grafo:
            grafo[ponto_destino] = []
        grafo[ponto_destino].append((ponto_origem, distancia))  # Adicione essa linha para lidar com arestas bidirecionais

    return grafo

# Função para encontrar o caminho mais curto usando Dijkstra
def dijkstra(grafo, ponto_inicial, ponto_final):
    distancias = {ponto: float('inf') for ponto in grafo}
    distancias[ponto_inicial] = 0
    visitados = set()

    while visitados != set(grafo):
        ponto_atual = None
        menor_distancia = float('inf')
        for ponto, distancia in distancias.items():
            if distancia < menor_distancia and ponto not in visitados:
                ponto_atual = ponto
                menor_distancia = distancia

        if ponto_atual is None:
            break

        visitados.add(ponto_atual)

        for vizinho, peso in grafo[ponto_atual]:
            distancia_calc = distancias[ponto_atual] + peso
            if distancia_calc < distancias[vizinho]:
                distancias[vizinho] = distancia_calc

    return distancias[ponto_final]

# Inserir seus dados de entrada aqui
ponto_escolhido = 98

# Criar o grafo
grafo = criar_grafo(l2)

# Encontrar o caminho mais curto do ponto escolhido até o ponto 0
melhor_caminho = round(dijkstra(grafo, ponto_escolhido, 0), 1)

print(f"O melhor caminho do ponto {ponto_escolhido} até o ponto 0 tem distância: {melhor_caminho}")
# Out:
# O melhor caminho do ponto 98 até o ponto 0 tem distância: 6.0

# %% [markdown]
# Algoritmo de Dijkstra considerando l2 e l3

# %%
# Função para criar o grafo a partir dos dados de entrada
def criar_grafo(l2, l3):
    grafo = {}
    for i in range(len(l2) // 3):
        ponto_origem = l2[i * 3]
        ponto_destino = l2[i * 3 + 1]
        distancia = l2[i * 3 + 2]
        if ponto_origem not in grafo:
            grafo[ponto_origem] = []
        grafo[ponto_origem].append((ponto_destino, distancia))
        if ponto_destino not in grafo:
            grafo[ponto_destino] = []
        grafo[ponto_destino].append((ponto_origem, distancia))  # Adicione essa linha para lidar com arestas bidirecionais

    for i in range(0, len(l3), 2):
        ponto1 = l3[i]
        ponto2 = l3[i + 1]
        if ponto1 not in grafo:
            grafo[ponto1] = []
        if ponto2 not in grafo:
            grafo[ponto2] = []
        grafo[ponto1].append((ponto2, 1))
        grafo[ponto2].append((ponto1, 1))

    return grafo

# Função para encontrar o caminho mais curto usando Dijkstra
def dijkstra(grafo, ponto_inicial, ponto_final):
    distancias = {ponto: float('inf') for ponto in grafo}
    distancias[ponto_inicial] = 0
    visitados = set()

    while visitados != set(grafo):
        ponto_atual = None
        menor_distancia = float('inf')
        for ponto, distancia in distancias.items():
            if distancia < menor_distancia and ponto not in visitados:
                ponto_atual = ponto
                menor_distancia = distancia

        if ponto_atual is None:
            break

        visitados.add(ponto_atual)

        for vizinho, peso in grafo[ponto_atual]:
            distancia_calc = distancias[ponto_atual] + peso
            if distancia_calc < distancias[vizinho]:
                distancias[vizinho] = distancia_calc

    return distancias[ponto_final]


# Ponto escolhido
ponto_escolhido = 98

# Criar o grafo
grafo = criar_grafo(l2, l3)

# Encontrar o caminho mais curto do ponto escolhido até o ponto 0
melhor_caminho = round(dijkstra(grafo, ponto_escolhido, 0), 1)

print(f"O melhor caminho do ponto {ponto_escolhido} até o ponto 0 tem distância: {melhor_caminho}")
# Out:
# O melhor caminho do ponto 98 até o ponto 0 tem distância: 6.0

# %% [markdown]
# Algoritmo de Dijkstra final comparando os dois apresentado acima

# %%
# Função para criar o grafo a partir dos dados de entrada
def criar_grafo(l2, l3=None):
    grafo = {}
    for i in range(len(l2) // 3):
        ponto_origem = l2[i * 3]
        ponto_destino = l2[i * 3 + 1]
        distancia = l2[i * 3 + 2]
        if ponto_origem not in grafo:
            grafo[ponto_origem] = []
        grafo[ponto_origem].append((ponto_destino, distancia))
        if ponto_destino not in grafo:
            grafo[ponto_destino] = []
        grafo[ponto_destino].append((ponto_origem, distancia))  # Adicione essa linha para lidar com arestas bidirecionais

    if l3 is not None:
        for i in range(0, len(l3), 2):
            ponto1 = l3[i]
            ponto2 = l3[i + 1]
            if ponto1 not in grafo:
                grafo[ponto1] = []
            if ponto2 not in grafo:
                grafo[ponto2] = []
            grafo[ponto1].append((ponto2, 1))
            grafo[ponto2].append((ponto1, 1))

    return grafo

# Função para encontrar o caminho mais curto usando Dijkstra
def dijkstra(grafo, ponto_inicial, ponto_final):
    distancias = {ponto: float('inf') for ponto in grafo}
    distancias[ponto_inicial] = 0
    visitados = set()

    while visitados != set(grafo):
        ponto_atual = None
        menor_distancia = float('inf')
        for ponto, distancia in distancias.items():
            if distancia < menor_distancia and ponto not in visitados:
                ponto_atual = ponto
                menor_distancia = distancia

        if ponto_atual is None:
            break

        visitados.add(ponto_atual)

        for vizinho, peso in grafo[ponto_atual]:
            distancia_calc = distancias[ponto_atual] + peso
            if distancia_calc < distancias[vizinho]:
                distancias[vizinho] = distancia_calc

    return distancias[ponto_final]


for i in consultas:
  ponto_escolhido = i

  # Criar o grafo
  grafo = criar_grafo(l2)

  # Encontrar o caminho mais curto do ponto escolhido até o ponto 0 usando o primeiro algoritmo
  melhor_caminho1 = round(dijkstra(grafo, ponto_escolhido, 0), 1)

  # Criar o grafo novamente para reiniciar as distâncias
  grafo = criar_grafo(l2, l3)

  # Encontrar o caminho mais curto do ponto escolhido até o ponto 0 usando o segundo algoritmo
  melhor_caminho2 = round(dijkstra(grafo, ponto_escolhido, 0), 1)

  # Verificar qual algoritmo teve a menor distância
  if melhor_caminho1 <= melhor_caminho2:
      print("victory")
  else:
      print("defeat")
# Out:
# defeat
